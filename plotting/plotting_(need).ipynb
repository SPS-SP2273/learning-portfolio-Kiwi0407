# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# ## 1 A simple plot

# %% [markdown]
# ### 1.1 Let’s look at some code.

# %%
from matplotlib import pyplot as plt

# %%
# Your code here

# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, color='red', linestyle='dashed', label='Y values')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# for jupyter, output will be shown even if plt.show() is gone
# plotting functions usually have default values
# plt.plot(x, y)

# %% [markdown]
# |**Long form**|**Abbreviation**|
# |:--|--:|
# |`color`|`c`|
# |`linestyle`|`ls`|
# |`linewidth`|`lw`|

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y = [0, 2, 4, 6, 8, 10, 12]

plt.plot(x, y, color='red', linestyle='dashed', linewidth=2)

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y = [0, 2, 4, 6, 8, 10, 12]

plt.plot(x, y, c='red', ls='dashed', lw=2)

# %% [markdown]
# ### 1.2 Adding another plot

# %%
# Your code here
# addition of a blue line graph
# by itself, it looks like this:

plt.plot(x, y_2, color='blue', label='Y2 values')

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Lets start plotting
plt.plot(x, y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(x, y_2, color='blue', label='Y2 values')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 1.3 Yet another plot but with error bars

# %%
# Your code here

# plotting the green graph by itself:

# plt.errorbar(x, y_3, xerr = x_error, yerr = y_error, 
             #color = "green", label = "Y3 with errors")

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(x, y_2, color='blue', label='Y2 values')
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             color='green', label='Y3 with errors')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 1.4 Experiment, Experiment, Experiment

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]

#plt.plot(x, y_1, color)
plt.grid(alpha = .1, color = 'blue', linestyle = 'dashed', linewidth = 2)
#plt.plot(label = 'test')
#plt.legend(loc = 'upper left')

# alpha is the transparency of a graph plot
# more transparent = lower than 1
# less transparent = greater than 1
# works with python IDE apart from jupyter -.-

# %%
# Your code here

x = [0, 1, 2, 3, 4, 5, 6]
y = [0, 2, 4, 6, 8, 10, 12]

# Let's start plotting
plt.plot(x, y, color = 'blue', linestyle = '-', label='test')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.1)
#plt.legend(loc = 'lower right')
plt.show()

# if location was not specified 
# the legend will not be plotted on graph

# %% [markdown]
# ### 1.5 Better with NumPy

# %%
# Your code here

import numpy as np

# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')
plt.show()

# %% [markdown]
# ### 1.6 Adding mathematical functions

# %%
# Your code here

x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.7 We need another axis!

# %%
# Your code here

# using the command twinx()

x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.legend(loc='lower left')

# This creates a new y-axis for the plot that comes after
# which is the sin(x) graph here
plt.twinx()
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend(loc='lower right')

plt.show()

# there are 2 'legend()' calls, one for each axis

# %%
# using np.linspace

x = np.linspace(0, 6, 100)
# 0 is the start number
# 6 is the stop number
# 100 is the total number of data points

# x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.legend(loc='lower left')

# This creates a new y-axis for the plot that comes after
# which is the sin(x) graph here
plt.twinx()
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# ### 1.8 Saving to disc

# %%
# Your code here
# saving to disc if u wanna use plot in presentation

# matplotlib can export into various formats
# function 'savefig()'
# specify format with extension
# specify resolution with dots-per-inch ('dpi')

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.legend(loc='lower left')

# This creates a new y-axis for the plot that comes after
plt.twinx()
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend(loc='lower right')

#plt.savefig('simple-plot.png', dpi=150)
# file saved in the same folder as this jupyter notebook

# %%
# to save file to somewhere else

# for Mac OS X
# plt.savefig('~/Desktop/simple-plot.png', dpi=150)

# for windows
# plt.savefig('C://Desktop/simple-plot.png', dpi=150)

# for JPEG format, 'simple-plot.jpeg' is used
# increase resolution by increasing dpi

# %% [markdown]
# ## 2 A real example: Global Warming

# %% [markdown]
# ### 2.1 Plotting data from files

# %%
# Your code here

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

# %%
plt.plot(date, anomaly, alpha = .5)
plt.ylim([-8,  8])

# eh @.@ looks diff sia oh wellz
# Out:
# (-8.0, 8.0)

# %%
# adding horizontal line at zero value
# 'hlines()' needs a y-value, starting and ending values for x

plt.plot(date, anomaly, alpha = .5)
plt.ylim([-8,  8])
plt.hlines(0, date[0], date[-1], linestyle = '--', colors = 'grey')

# %% [markdown]
# http://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html

# %%
# this line must be included right at top >:3
plt.style.use('fivethirtyeight')
plt.plot(date, anomaly, alpha = .5)
plt.ylim([-8,  8])
plt.hlines(0, date[0], date[-1], linestyle = '--', colors = 'grey')

# errr idk if its cus the template was modified recently or what
# my titles? QAQ

# %%
# complete code:
plt.style.use('fivethirtyeight')

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')
plt.ylim([-8, 8])

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')
plt.show()

# %%
# reset to default style
plt.style.use('default')

# %% [markdown]
# ### 2.2 xkcd!

# %%
# Your code here
plt.xkcd()
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')
plt.ylim([-8, 8])

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')

plt.savefig('temperature xkcd.png', dpi = 200)

# eh ??? graph formed but
# why font not found ;-;
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %% [markdown]
# ## Exercise 1 :  Fill in the blanks

# %%
# Your solution here
# cus of xkcd above
plt.style.use('default')

# Some data for plotting
x = [0, 1, 2, 3, 4, 5]
y = [0, 4, 8, 12, 16, 20]
y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
x_err = .25 #* y

plt.errorbar(x, y, xerr = x_err, yerr = y_err,
             color = 'darkred', linestyle = 'dashed',
             marker = 'o', markerfacecolor = 'yellow',
             ecolor = 'black', capsize = 5,
             label = 'Y values with errors')

# xerr, yerr = error arrays of positive values
# color https://matplotlib.org/stable/gallery/color/named_colors.html
# markers https://matplotlib.org/stable/api/markers_api.html
# markerfacecolor = color of error markers
# ecolor (optional) = color of errorbar lines
# capsize (optional) = length of error bar caps in points

plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc = 'lower right')   # added in 'loc = '
#save_file_figure(plt, argv)                  # Hide
plt.show(block=False)
#plt.savefig('exercise_1.png', dpi = 200)

# %% [markdown]
# ## Exercise 2 :  A simple mathematical plot

# %%
# Your solution here

import numpy as np


# dealing with the function first:
x = np.linspace(0, 50, 300)
a = -x/10
sin_x = np.sin(x)
b = np.e ** a
y = b * sin_x
# print(y)  # to check if the formula is working

# time to actually plot
plt.plot(x, y, color='steelblue')
plt.ylim([-1, 1])
plt.xlabel('X', fontsize = 15, color = 'darkblue')
plt.ylabel('y', fontsize = 15, color = 'darkblue', rotation = 0)
plt.title('$y = e^{-x/10} sin(X)$')
plt.grid(alpha=.25)
plt.show()
#plt.savefig('exercise_2.png', dpi = 200)
