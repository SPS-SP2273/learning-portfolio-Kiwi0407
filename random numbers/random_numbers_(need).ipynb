# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Random Numbers (Need)</span></div>

# %% [markdown]
# ## 1 Random Numbers

# %% [markdown]
# ### 1.1 Real and Pseudo Random Numbers

# %%
# Your code here

# %% [markdown]
# ### 1.2 NumPy’s PRNG

# %%
# Your code here
import numpy as np

np.random.rand()                # Give one number
# Out:
# 0.06561199311429389

# %%
np.random.rand(10)              # Give ten numbers`
# Out:
# array([0.28935159, 0.83577877, 0.86588735, 0.34698249, 0.69613291,
#        0.14612319, 0.24615318, 0.84934857, 0.21450246, 0.25771873])

# %%
np.random.rand(5,2)             # Give five sets of 2

# all numbers are between 0 and 1
# numbers are likely to be uniformly distributed
# Out:
# array([[0.86489133, 0.66859013],
#        [0.36039957, 0.47416587],
#        [0.77451736, 0.94713482],
#        [0.88340993, 0.53919224],
#        [0.69539577, 0.9319947 ]])

# %%
n = 10000
random_numbers = np.random.rand(n)

# %%
# The numbers less than .5 must be about 50%
np.sum(random_numbers < .5) / n * 100
# Out:
# 49.830000000000005

# %%
# The numbers less than .25 must be about 25%
np.sum(random_numbers < .25) / n * 100
# Out:
# 24.94

# %%
# The numbers more than .75 must be about 25%
np.sum(random_numbers > .75) / n * 100
# Out:
# 25.3

# %% [markdown]
# ### 1.3 A simple graphical test

# %%
# Your code here

from matplotlib import pyplot as plt 

n = 10000
random_numbers = np.random.rand(n)

fig, ax = plt.subplots(nrows=1, ncols=2)

axis = ax[0]
axis.hist(random_numbers, bins=100, alpha=.25)
axis.set_xlabel("Value of random number")
axis.set_ylabel("Frequency")

axis = ax[1]
axis.scatter(range(n), random_numbers, alpha=.25)
axis.set_xlabel("Position in the random number list")
axis.set_ylabel("Value of random number")
# Out:
# Text(0, 0.5, 'Value of random number')

# %% [markdown]
# ### 1.4 Uniformly beyond \([0,1)\)

# %%
# Your code here

# use np.random.uniform()
# large set of random number [50, 100]

n = 10000
random_numbers = np.random.uniform(low=50, high=100, size=n)

fig, ax = plt.subplots(nrows=1, ncols=2)

axis = ax[0]
axis.hist(random_numbers, bins=100, alpha=.25)
axis.set_xlabel("Value of random number")
axis.set_ylabel("Frequency")

axis = ax[1]
axis.scatter(range(n), random_numbers, alpha=.25)
axis.set_xlabel("Position in the random number list")
axis.set_ylabel("Value of random number")
# Out:
# Text(0, 0.5, 'Value of random number')

# %% [markdown]
# ### 1.5 ‘seeding’ a PRNG

# %%
# Your code here
# same set of numbers
# seed, integer number that 'kicks off' the PRNG algorithm

np.random.randint(0, 100, 10)     # Ten integers between 0 and 100
# Out:
# array([85, 96, 20,  0, 73,  6,  2,  4, 93, 62])

# %%
np.random.randint(0, 100, 10)     # Another ten integers between 0 and 100
# Out:
# array([52, 17, 95, 25, 46, 68, 53, 23, 16, 68])

# %%
np.random.seed(1234)              # Specifying a seed
np.random.randint(0, 100, 10)     # Ten integers between 0 and 100
# Out:
# array([47, 83, 38, 53, 76, 24, 15, 49, 23, 26])

# %%
np.random.seed(1234)
np.random.randint(0, 100, 10)     # Same ten integers between 0 and 100
# Out:
# array([47, 83, 38, 53, 76, 24, 15, 49, 23, 26])

# %% [markdown]
# ## 2 Simulating a Magic-8 Ball

# %%
def shake_magic_8():
    '''
    Function to simulate a Magic-8 ball!
    '''
    options = ['It is certain.', 'It is decidedly so.',
               'Without a doubt.', 'Yes definitely.',
               'You may rely on it.', 'As I see it, yes.',
               'Most likely.', 'Outlook good.',
               'Yes.', 'Signs point to yes.',
               'Reply hazy, try again.', 'Ask again later.',
               'Better not tell you now.', 'Cannot predict now.',
               'Concentrate and ask again.', 'Don\'t count on it.',
               'My reply is no.', 'My sources say no.',
               'Outlook not so good.', 'Very doubtful.']

    return np.random.choice(options)  # picks one randomly

# %%
questions = ['Will I be pretty?',
             'Will I be rich?',
             'Will I be in trouble?']

for question in questions:
    print(f'Q: {question}')
    print(f'A: {shake_magic_8()}\n')
# Out:
# Q: Will I be pretty?
# A: Ask again later.
#
# Q: Will I be rich?
# A: Better not tell you now.
#
# Q: Will I be in trouble?
# A: My reply is no.

# %% [markdown]
# ## 3 Flipping Coins

# %% [markdown]
# ### 3.1 A fair coin

# %%
# Your code here
np.random.choice(['Head', 'Tails'])
# Out:
# 'Head'

# %%
no_of_coins = 10
np.random.choice(['Head', 'Tails'], no_of_coins)
# Out:
# array(['Tails', 'Head', 'Tails', 'Tails', 'Head', 'Head', 'Tails', 'Head',
#        'Head', 'Tails'], dtype='<U5')

# %%
# any number in (0, .5] to be tails
# any number in (.5, 1) to be heads

def flip_coins(no_of_coins=1, probability=.5):
    '''
    Returns the number of values greater that 
    `probability` (considered as 'Heads').
    '''
    results = np.random.rand(no_of_coins)
    no_of_heads = np.sum(results > probability)
    return no_of_heads

# %%
no_of_coins = 1_000
no_of_heads = flip_coins(no_of_coins)
print(f'Number of heads: {no_of_heads/no_of_coins*100:.2f}%')
# Out:
# Number of heads: 51.60%

# %% [markdown]
# ### 3.2 A biased coin

# %%
# Your code here
# probability of .7 for head

no_of_coins = 1_000
no_of_heads = flip_coins(no_of_coins, probability = .3)
print(f'Number of heads: {no_of_heads/no_of_coins*100:.2f}%')
# Out:
# Number of heads: 66.70%

# %% [markdown]
# ### 3.3 A flipping experiment

# %%
# Your code here

no_of_repeats = 10_000
result = [flip_coins(no_of_coins=10) for _ in range(no_of_repeats)]
no_of_heads, heads_counts = np.unique(result, return_counts=True)

# %%
heads_probability = heads_counts/no_of_repeats

# %%
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = (10,5)
plt.bar(no_of_heads, heads_counts);
plt.xlabel('No of heads')
plt.ylabel(f'Frequency out of {no_of_repeats}')
plt.table([no_of_heads, heads_counts, heads_probability],
          rowLabels=['No of Heads', 'Frequency', 'PRNG Probability'],
          loc='bottom',
          bbox=[0, -0.5, 1, 0.3])

# binomial distribution

# %%
from scipy.stats import binom

# %%
binom.pmf(k=7, n=10, p=.5)
# Out:
# 0.11718749999999999

# %%
# binomial distribution gives probability of 7 heads
# when we throw 10 fair coins

no_of_heads = 7
binomial_probabilities = binom.pmf(k=no_of_heads, n=10, p=.5)

# %% [markdown]
# ## Exercise 1 :  12C, 13C

# %% [markdown]
# Carbon has two stable, non-radioactive isotopes, 12C and 13C, with relative isotopic abundances of, respectively, 98.89% and 1.11%.
#
# 1. What are the mean and the standard deviation for the number of 13C atoms in a molecule of cholesterol (C27H44O)?
#
# - Hint: Treat 13C as Heads.
#
# 2. What is the probability that a cholesterol molecule has no atoms of 13C?
#
# - Don’t use any functions from SciPy like binom()

# %%
# Your solution here
# are the values supposed to be fixed or fluctuate depending on probability?
# part 1

import numpy as np

def c_count(no_of_c = 27, probability = .9889):
    results = np.random.rand(no_of_c)
    no_of_heads = np.sum(results > probability)
    return no_of_heads

# no_of_c = 27
# no_of_heads = c_count(no_of_c, probability = .9889)
# print(f'Number of 13C: {no_of_heads}')
# number of 13C as heads

no_of_c = 27
data = [c_count(no_of_c, probability = .9889) for i in range(10000)]
mean = sum(data)/len(data)
s_deviate = np.std(data)
print(f'The mean is {mean} and the standard deviation is {s_deviate:.3f}')
# Out:
# The mean is 0.2951 and the standard deviation is 0.537

# %%
# part 2
# continuing from above cell

#mean = data/no_of_c
#print(mean)
#no_of_heads = np.unique(data, return_counts = True)

def c_count(no_of_c = 27, probability = .0111):
    results = np.random.rand(no_of_c)
    no_of_heads = np.sum(results > probability)
    return no_of_heads

no_of_repeat = 1000
outcome = [c_count(no_of_c = 27, probability = .0111) for i in range(no_of_repeats)]
no_of_heads, heads_count = np.unique(outcome, return_counts = True)
prob_heads = heads_count/no_of_repeats
prob_heads[-1]
#prob_tails = 1 - prob_heads

#from matplotlib import pyplot as plt

#plt.bar(no_of_heads, heads_count);
#plt.xlabel('Number of Heads')
#plt.ylabel(f'Frequency of Heads out of {no_of_repeats}')
#plt.table([no_of_heads, heads_count, prob_heads, prob_tails], rowLabels = ['Number of Heads', 'Frequency of Heads', 'Head Probability', 'Tail Probability'], bbox = [0, -0.5, 1, 0.3])
#fig.tight_layout()
# Out:
# 0.7368
